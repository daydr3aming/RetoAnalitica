# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Actividad evaluable
# #### Mapas de calor y boxplots
# Rogelio Guzman Cruzado - A01639914

# %%
df = pd.read_csv('iris.csv')

# %%
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
fig = plt.figure(figsize=(8, 5))
numeric = df.drop('Species', axis=1)
corr = numeric.corr()
sns.heatmap(data = corr, vmin= -1, vmax = 1, cmap = "OrRd", annot = True)
plt.show()

# %%
fig = plt.figure(figsize=(8, 5))
sns.boxplot(x = 'Species', y = 'Sepal.Length', data = df)
plt.title('Sepal Length by Species')
plt.show()
# Out:
# c:\Users\rogel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\rogel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\rogel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Sepal Length by Species')

# %%
fig, axs = plt.subplots(2, 2, figsize=(8, 5))
sns.histplot(data = df, x = 'Sepal.Length', hue = 'Species', bins=10, kde = True, ax = axs[0][0])
sns.histplot(data = df, x = 'Sepal.Width', hue = 'Species', bins=10, kde = True, ax = axs[0][1])
sns.histplot(data = df, x = 'Petal.Length', hue = 'Species', bins=10, kde = True, ax = axs[1][0])
sns.histplot(data = df, x = 'Petal.Width', hue = 'Species', bins=10, kde = True, ax = axs[1][1])
# Out:
# c:\Users\rogel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\rogel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\rogel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## Preguntas
# #### ¿Hay alguna variable que no aporta información?
# Especies en general no aporta información para el analísis de correlación y temporales de los datos. Solo sirve como una variable descriptiva
# #### Si tuvieras que eliminar variables, ¿Cuáles quitarías y porqué?
# Quitaría las variables cualitativas en situaciones donde necesite solo valores númericos, en este caso sería "Species"
# #### ¿Existen variables que tengan datos extraños?
# No realmente.
# #### Si comparas las variables, ¿están en rangos similares? ¿Qué que esto afecte?
# Si están en rangos numéricos similares, esto puede afectar al analísis en permitir un analísis menos disperso y más preciso.
# #### ¿Puedes encontrar grupos que se parezcan? ¿Qué grupos son estos?
# Versicolor y Virginia son similares, mientras que Setosa es generalmente más distinta.
